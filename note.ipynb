# %%
import pandas as pd

data = [
    ["2025-01-03", "Andi Pratama", "Pusing setelah olahraga", "Istirahat dan cek tekanan darah", "Paracetamol", "Dipulangkan", "Kondisi membaik"],
    ["2025-01-04", "Siti Aisyah", "Nyeri perut", "Kompres hangat dan observasi", "Antasida", "Dirawat", "Masih dipantau"],
    ["2025-01-05", "Budi Santoso", "Luka lecet di kaki", "Membersihkan luka dan perban", "Povidone Iodine", "Dipulangkan", "Tidak ada pendarahan lanjut"],
    ["2025-01-06", "Rina Oktaviani", "Demam dan sakit tenggorokan", "Cek suhu dan istirahat", "Paracetamol", "Dirujuk", "Suhu 38.6°C"],
    ["2025-01-07", "Dimas Saputra", "Batuk dan pilek", "Observasi di UKS", "Obat batuk sirup", "Dirawat", "Disarankan istirahat"],
    ["2025-01-08", "Nabila Putri", "Sakit kepala ringan", "Istirahat dan minum air putih", "-", "Dipulangkan", "Diduga kurang minum"],
    ["2025-01-09", "Rizky Maulana", "Mual saat pelajaran", "Istirahat dan observasi", "Minyak angin", "Dipulangkan", "Tidak muntah"],
    ["2025-01-10", "Aulia Rahman", "Tergores benda tajam", "Membersihkan luka", "Povidone Iodine", "Dipulangkan", "Luka kecil"],
    ["2025-01-11", "Putri Amelia", "Pusing dan lemas", "Cek tekanan darah", "Vitamin B kompleks", "Dirawat", "Tekanan darah rendah"],
    ["2025-01-12", "Fajar Nugroho", "Nyeri otot setelah olahraga", "Kompres hangat", "Balsem otot", "Dipulangkan", "Disarankan peregangan"],
    ["2025-01-13", "Intan Permata", "Sakit perut saat haid", "Istirahat di UKS", "Paracetamol", "Dirawat", "Keluhan berkurang"],
    ["2025-01-14", "Yoga Pratama", "Batuk ringan", "Observasi singkat", "Obat batuk sirup", "Dipulangkan", "Tidak ada demam"],
    ["2025-01-15", "Zahra Khadijah", "Demam tinggi", "Cek suhu tubuh", "Paracetamol", "Dirujuk", "Disarankan ke puskesmas"],
    ["2025-01-16", "Ilham Fauzi", "Pusing setelah tidak sarapan", "Istirahat dan makan ringan", "-", "Dipulangkan", "Kondisi stabil"],
    ["2025-01-17", "Maya Lestari", "Luka jatuh ringan", "Membersihkan luka dan perban", "Povidone Iodine", "Dipulangkan", "Diminta kontrol jika nyeri"],
    ["2025-01-18", "Salsabila", "Sakit kepala setelah belajar lama", "Istirahat dan observasi", "Paracetamol", "Dipulangkan", "Diduga kelelahan"],
    ["2025-01-22", "Salsabila", "Nyeri perut ringan", "Kompres hangat", "Antasida", "Dipulangkan", "Tidak ada muntah"],
    ["2025-01-28", "Salsabila", "Pusing saat upacara", "Cek tekanan darah dan istirahat", "-", "Dipulangkan", "Tekanan darah normal"],
    ["2025-02-03", "Salsabila", "Batuk kering", "Observasi singkat", "Obat batuk sirup", "Dipulangkan", "Tanpa demam"],
    ["2025-02-10", "Salsabila", "Lemas karena terlambat makan", "Istirahat dan makan ringan", "-", "Dipulangkan", "Kondisi membaik"]
]


columns = ["tanggal", "nama_siswa", "keluhan", "tindakan", "obat", "status", "catatan"]

df = pd.DataFrame(data, columns=columns)
df.to_csv("riwayat_kunjungan.csv", index=False)

# %%
import pandas as pd

penyakit = [
    {
        "nama": "Flu",
        "pengertian": "Infeksi saluran pernapasan atas yang disebabkan oleh virus",
        "gejala": "Pilek, batuk, sakit kepala, demam ringan",
        "penyebab": "Virus influenza dan penurunan daya tahan tubuh",
        "pengobatan": "Istirahat cukup, minum obat pereda gejala, perbanyak cairan"
    },
    {
        "nama": "Demam",
        "pengertian": "Kondisi meningkatnya suhu tubuh di atas normal",
        "gejala": "Tubuh panas, menggigil, lemas",
        "penyebab": "Infeksi virus atau bakteri",
        "pengobatan": "Istirahat, minum air putih, dan obat penurun panas"
    },
    {
        "nama": "Sakit Perut",
        "pengertian": "Rasa nyeri atau tidak nyaman pada area perut",
        "gejala": "Perut mulas, mual, kembung",
        "penyebab": "Terlambat makan, makanan pedas, atau gangguan pencernaan",
        "pengobatan": "Kompres hangat dan obat maag"
    },
    {
        "nama": "Pusing",
        "pengertian": "Kondisi kepala terasa berat atau berputar",
        "gejala": "Kepala terasa berat, mual, pandangan kabur",
        "penyebab": "Kurang istirahat, dehidrasi, atau tekanan darah rendah",
        "pengobatan": "Istirahat dan minum air putih"
    }
]

df_penyakit = pd.DataFrame(penyakit)
df_penyakit.to_csv("data_penyakit.csv", index=False)

# %%
obat = [
    {
        "nama": "Paracetamol",
        "pengertian": "Obat untuk menurunkan demam dan meredakan nyeri ringan",
        "manfaat": "Mengurangi demam dan sakit kepala",
        "dosis": "1 tablet, maksimal 3 kali sehari",
        "efek_samping": "Mual ringan jika dikonsumsi berlebihan"
    },
    {
        "nama": "Antasida",
        "pengertian": "Obat untuk menetralkan asam lambung",
        "manfaat": "Meredakan nyeri lambung dan perut mulas",
        "dosis": "1–2 tablet setelah makan",
        "efek_samping": "Sembelit atau diare ringan"
    },
    {
        "nama": "Obat Batuk Sirup",
        "pengertian": "Obat cair untuk meredakan batuk",
        "manfaat": "Mengurangi batuk kering atau berdahak",
        "dosis": "1 sendok takar, 3 kali sehari",
        "efek_samping": "Mengantuk"
    },
    {
        "nama": "Povidone Iodine",
        "pengertian": "Antiseptik untuk membersihkan luka",
        "manfaat": "Mencegah infeksi pada luka terbuka",
        "dosis": "Dioleskan secukupnya pada luka",
        "efek_samping": "Iritasi ringan pada kulit sensitif"
    }
]

df_obat = pd.DataFrame(obat)
df_obat.to_csv("data_obat.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tanggal     15 non-null     object
#  1   nama_siswa  15 non-null     object
#  2   keluhan     15 non-null     object
#  3   tindakan    15 non-null     object
#  4   obat        15 non-null     object
#  5   status      15 non-null     object
#  6   catatan     15 non-null     object
# dtypes: object(7)
# memory usage: 972.0+ bytes
